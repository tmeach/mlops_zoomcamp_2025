# %%
import pandas as pd
import pickle

# %%
df = pd.read_parquet('/Users/pitsuevt/work_main/learning/datatalks/mlops_zoomcamp_2025/02-experiment-tracking/homework/data/green_tripdata_2023-01.parquet')

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
# 1         2  2023-01-01 00:51:03   2023-01-01 00:57:49                  N
# 2         2  2023-01-01 00:35:12   2023-01-01 00:41:32                  N
# 3         1  2023-01-01 00:13:14   2023-01-01 00:19:03                  N
# 4         1  2023-01-01 00:33:04   2023-01-01 00:39:02                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           166           143              1.0           2.58
# 1         1.0            24            43              1.0           1.81
# 2         1.0           223           179              1.0           0.00
# 3         1.0            41           238              1.0           1.30
# 4         1.0            41            74              1.0           1.10
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# ...

# %%
df['PU_DO'] = df['PULocationID'].astype(str) + '_' + df['DOLocationID'].astype(str)

# %%
categorical = ['PU_DO']
numerical = ['trip_distance']

# %%
df[categorical + numerical]
# Out:
#          PU_DO  trip_distance
# 0      166_143           2.58
# 1        24_43           1.81
# 2      223_179           0.00
# 3       41_238           1.30
# 4        41_74           1.10
# ...        ...            ...
# 68206    49_62        4070.82
# 68207   10_205           2.14
# 68208    66_37           3.44
# 68209  225_189           3.03
# 68210  256_140           5.82
#
# [68211 rows x 2 columns]

# %%
df[categorical + numerical].to_dict(orient='records')
# Out:
# [{'PU_DO': '166_143', 'trip_distance': 2.58},
#  {'PU_DO': '24_43', 'trip_distance': 1.81},
#  {'PU_DO': '223_179', 'trip_distance': 0.0},
#  {'PU_DO': '41_238', 'trip_distance': 1.3},
#  {'PU_DO': '41_74', 'trip_distance': 1.1},
#  {'PU_DO': '41_262', 'trip_distance': 2.78},
#  {'PU_DO': '181_45', 'trip_distance': 3.8},
#  {'PU_DO': '24_75', 'trip_distance': 1.88},
#  {'PU_DO': '41_166', 'trip_distance': 1.11},
#  {'PU_DO': '24_140', 'trip_distance': 4.22},
#  {'PU_DO': '255_234', 'trip_distance': 4.8},
#  {'PU_DO': '75_140', 'trip_distance': 1.99},
#  {'PU_DO': '75_148', 'trip_distance': 7.08},
#  {'PU_DO': '66_255', 'trip_distance': 3.23},
#  {'PU_DO': '255_186', 'trip_distance': 5.91},
#  {'PU_DO': '195_210', 'trip_distance': 11.3},
#  {'PU_DO': '83_129', 'trip_distance': 1.3},
#  {'PU_DO': '97_68', 'trip_distance': 8.28},
#  {'PU_DO': '7_260', 'trip_distance': 2.02},
#  {'PU_DO': '41_75', 'trip_distance': 0.96},
#  {'PU_DO': '75_74', 'trip_distance': 0.96},
# ...
