# %% [markdown]
# ## Homework
#
# The goal of this homework is to train a simple model for predicting the duration of a ride, but use Mage for it.
#
# We'll use [the same NYC taxi dataset](https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page), the Yellow taxi data for 2023.

# %% [markdown]
# ## Question 1. Run Mage
# First, let's run Mage with Docker Compose. Follow the quick start guideline.
#
# What's the version of Mage we run?

# %% [markdown]
# ![image.png](attachment:6f8413a6-d702-4874-8a8e-d02d36d4cce3.png)

# %% [markdown]
# ### Answer:
# - v0.9.70

# %% [markdown]
# ## Question 2. Creating a project
# Now let's create a new project. We can call it "homework_03", for example.
#
# How many lines are in the created metadata.yaml file?
#
# - 35
# - 45
# - 55
# - 65

# %% [markdown]
# ![image.png](attachment:a5ed39b4-e2c4-42b3-96a6-b3148b1fbade.png)

# %% [markdown]
# ### Answer:
# - 55

# %% [markdown]
# ## Question 3. Creating a pipeline
# Let's create an ingestion code block.
#
# In this block, we will read the March 2023 Yellow taxi trips data.
#
# How many records did we load?
#
# - 3,003,766
# - 3,203,766
# - 3,403,766
# - 3,603,766

# %% [markdown]
# ### Answer:
# - 3403766

# %%
import pandas as pd

# if 'data_loader' not in globals():
#     from mage_ai.data_preparation.decorators import data_loader
# if 'test' not in globals():
#     from mage_ai.data_preparation.decorators import test

#@data_loader
def load_data(*args, **kwargs):
    """
    Template code for loading data from any source.

    Returns:
        Anything (e.g. data frame, dictionary, array, int, str, etc.)
    """
    dff = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet')

    return df


#@test
def test_output(output, *args) -> None:
    """
    Template code for testing the output of the block.
    """
    if output is not None:
        print("Test passed successfully!")
    else:
        print("Test failed: The output is undefined")

# %%
ff = load_data()

# %%
ss = test_output(ff)

# %%
test_output(ff)
# Out:
# Test passed successfully!
